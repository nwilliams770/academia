# %% [markdown]
# # Problem Set 4

# %% [markdown]
# ## 3.5

# %% [markdown]
# 2.

# %% [markdown]
# 21.

# %% [markdown]
# 37.

# %% [markdown]
# 41.

# %% [markdown]
# 44.

# %% [markdown]
# ## 3.6
