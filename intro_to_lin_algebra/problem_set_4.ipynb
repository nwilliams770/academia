# %% [markdown]
# # Problem Set 4

# %% [markdown]
# ## 3.5

# %% [markdown]
# 2.

# %% [markdown]
# a.
#
# $C(A)$ - $\{ (1, 2) \}$ - $\dim(C(A)) = 1$
#
# $R(A)$ - $\{ (1, 2, 4) \}$ - $\dim(R(A)) = 1$
#
# $N(A)$
#
# $$
# x = x_{2}
# \begin{bmatrix}
# -2 \\
# 1 \\
# 0
# \end{bmatrix}
# + x_3
# \begin{bmatrix}
# -4 \\
# 0 \\
# 1
# \end{bmatrix}
# $$
#
# $N(A^{T})$- $\{ (-2, 1) \}$ - $\dim(R(A^{T})) = 1$
#
#
# b.
#
# $C(B)$
#
# $$
# \{
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}
# ,
# \begin{bmatrix}
# 2 \\
# 5
# \end{bmatrix}
# \}
# $$
#
# $\dim(C(B)) = 2$
#
# $R(B)$ - $\{ (1, 2, 4), (0, 1, 0) \}$ - $\dim(R(B)) = 2$
#
# $N(B)$
#
# $$
# \{
# \begin{bmatrix}
# -4 \\
# 0 \\
# 1
# \end{bmatrix}
# \}
# $$
#
# $\dim(N(B)) = 1$
#
# $R(B_{T})$ - $\{ \}$ - $\dim(R(B_{T})) = 0$

# %% [markdown]
# 20.

# %% [markdown]
# a.
#
# $$
# N(A) =
# \{
# \begin{bmatrix}
# -1 \\
# 2 \\
# 0 \\
# 0
# \end{bmatrix}
# ,
# \begin{bmatrix}
# -\frac{1}{4} \\
# 0 \\
# -3 \\
# 1
# \end{bmatrix}
# \}
# $$
#
# The solutions to $N(A)$ are orthogonal to $A$. Considering the fact that $Ax = 0$ is just a dot product of $x$ and each row of $A$ and what it means for the dot product to equal $0$.
#
# b.
# $A^{T}y = 0$ has one independent solution: the **last row of $E^{-1}$**. The last row of $E^{-1}$ encodes the orthogonal vector in the left null space $N(A^T$, as the inverse matrix $E^{-1}$ reflects the orthogonal relationships between the row space and null space.
